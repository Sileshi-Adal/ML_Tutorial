# %%
##### import numpy as np
import imageio
import scipy.misc
from PIL import Image
from matplotlib import pyplot as plt
import pandas as pd



#im = Image.load("DroneFrameHelsinki.jpeg")
image = Image.open('DroneFrameHelsinki.jpeg')

fig = plt.figure(figsize=(20,20))
plt.imshow(image)
plt.axis([2000,3000,500,1500])

df=pd.read_csv('gTruth30Nov_fountain.csv', sep=',')
df.values
X = df.values # convert the data frame to numpy array
plt.scatter(X[:,1], X[:,0],s=6, c='b', marker='.')

df=pd.read_csv('gTruth30Nov_back.csv', sep=',')
df.values
X = df.values # convert the data frame to numpy array
plt.scatter(X[:,1], X[:,0],s=6, c='r', marker='.')

df=pd.read_csv('gTruth30Nov_ppl.csv', sep=',')
df.values
X = df.values # convert the data frame to numpy array
plt.scatter(X[:,1], X[:,0],s=600, c='g', marker='.')
plt.show()

# %%
print(test.shape)
# Out:
# (2160, 4096, 3)

# %%
from sklearn.feature_extraction import image

patches = image.extract_patches_2d(test, (64, 64),max_patches=600)

# %%
print(patches.shape)
# Out:
# (600, 64, 64, 3)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os

nr_rows = 60 
nr_cols=10
fig, axs = plt.subplots(nr_rows, nr_cols,figsize=(10,20))

print(axs.shape)
base_dir = "Patches14Nov"

for iter_rows in range(nr_rows):
    for iter_cols in range(nr_cols):
         patch_idx=iter_rows*nr_cols+iter_cols
         axs[iter_rows,iter_cols].imshow(patches[patch_idx,:,:,:])
         axs[iter_rows,iter_cols].axis('off')
         im = Image.fromarray(patches[patch_idx,:,:,:])
         
         filename = "patch_"+ str(patch_idx)+".jpeg"
         fullpath = os.path.join(base_dir, filename)
         im.save(fullpath)
            
fig.tight_layout()
plt.show()
# Out:
# (60, 10)
