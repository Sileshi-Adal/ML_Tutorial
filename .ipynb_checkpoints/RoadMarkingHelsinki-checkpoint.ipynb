# %%
from owslib.wms import WebMapService
wms = WebMapService('https://kartta.hel.fi/ws/geoserver/avoindata/wms', version='1.1.1')

# %%
list(wms.contents)
# Out:
# ['avoindata:Kantakartta',
#  'avoindata:Kantakartta_harmaa',
#  'avoindata:Kantakartta_varillinen',
#  'avoindata:Kantakartta_rajat',
#  'avoindata:Kantakartta_valkoinen',
#  'avoindata:Kantakartan_maastotiedot',
#  'avoindata:Kantakartta_pohja',
#  'avoindata:Kantakartta_paakohteet',
#  'avoindata:Karttasarja',
#  'avoindata:Karttasarja_harmaa',
#  'avoindata:Kiinteistokartta',
#  'avoindata:Kiinteistokartan_maastotiedot',
#  'avoindata:Kiinteistokartta_pohja',
#  'avoindata:Kiinteistokartta_paakohteet',
#  'avoindata:Opaskartta_Helsinki',
#  'avoindata:Opaskartta_Helsinki_harmaa',
#  'avoindata:Opaskartta_Helsinki_harvanimi',
#  'avoindata:Opaskartta_Helsinki_harvanimi_harmaa',
#  'avoindata:Opaskartta_Helsinki_4m',
#  'avoindata:Opaskartta_Helsinki_4m_harmaa',
#  'avoindata:Opaskartta_alue',
#  'avoindata:Opaskartta_alueenviiva',
#  'avoindata:Opaskartta_muuviiva',
#  'avoindata:Opaskartta_nimisto',
#  'avoindata:Opaskartta_harvanimi_nimisto',
#  'avoindata:Opaskartta_PKS',
# ...

# %%
layer='avoindata:Ortoilmakuva_2019_5cm'

print(wms[layer].boundingBox)
print(wms[layer].boundingBoxWGS84)
print(wms[layer].crsOptions)

#img = wms.getmap(layers=['avoindata:Ortoilmakuva_2019_5cm'],srs='EPSG:4326',bbox=(24.939,60.161,24.945,60.164),size=(5000,5000),format='image/jpeg',transparent=True)
img = wms.getmap(layers=['avoindata:Ortoilmakuva_2019_5cm'],srs='EPSG:4326',bbox=(24.92,60.15,24.99,60.20),size=(1500,1500),format='image/jpeg',transparent=True)
# Out:
# (25487000.0, 6655000.0, 25516000.0, 6690000.0, 'EPSG:3879')
# (24.764732945863038, 60.0080107531311, 25.289558715996222, 60.322459856333225)
# ['EPSG:3879', 'EPSG:4326', 'EPSG:3877', 'EPSG:3873', 'EPSG:3874', 'EPSG:3067', 'EPSG:3046', 'EPSG:3878', 'EPSG:3387', 'EPSG:3883', 'EPSG:3048', 'EPSG:3876', 'EPSG:3882', 'EPSG:3875', 'EPSG:2391', 'EPSG:3047', 'EPSG:3857', 'EPSG:3386', 'EPSG:3885', 'EPSG:2393', 'EPSG:4258', 'EPSG:2394', 'EPSG:2392', 'EPSG:3880', 'EPSG:4123', 'EPSG:3884', 'EPSG:3881']

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
import datetime
import numpy as np
import matplotlib.pyplot as plt

out = open('out.jpg', 'wb')
out.write(img.read())
out.close()
plt.figure(
    figsize=(20, 20))
plt.imshow(mpimg.imread('out.jpg'))
